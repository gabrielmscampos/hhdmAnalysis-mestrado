# %%
import h5py
import numpy as np
import pandas as pd

# %%
basedir = "/home/gamoreir/SanDisk/physics/hhdmAnalysis"
fpath = f"{basedir}/local_output/Data_DoubleMu_test_H_16_files_0_0/selection.h5"
f = h5py.File(fpath, "r")

# %%
df = {}

for variable in f["scalars"]:
    hdf_path = f"scalars/{variable}"
    df[variable] = np.array(f[hdf_path])

df = pd.DataFrame(df)

# %%
df.head()
# Out:
#    DatasetID  Dijet_H_deltaPhi  Dijet_H_pt    Dijet_M  Dijet_deltaEta  \
# 0    1600000          0.753212  263.829498  50.112049        1.120178
# 1    1600000          0.753212  263.829498   3.654297        0.000000
# 2    1600000          1.195739   68.274315  17.416555        0.070312
# 3    1600000          1.195739   68.274315  20.328125        0.000000
# 4    1600000          1.195739   68.274315   9.226562        0.000000
#
#      Dijet_pt          HT  Jet_abseta_max  LeadingJet_btag_score  \
# 0   52.237717   84.156250        3.130859               0.070496
# 1   30.609375   30.609375        2.671875               0.070496
# 2   44.430668   46.421875        2.212402               0.074036
# 3  107.562500  107.562500        1.361328               0.074036
# 4   57.000000   57.000000        0.758423               0.074036
#
#    LeadingJet_eta  ...  RecoLepID  RegionID  SubLeadingJet_btag_score  \
# 0       -0.747681  ...         13        -1                  0.013344
# ...
